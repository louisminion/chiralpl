# %%
import pandas as pd

import matplotlib.pyplot as plt

f = r'C:\Users\louis\Documents\GitHub\chiralpl\source\NOCT_JAGG_abs.csv'
f = pd.read_csv(f,skiprows=3)
f = f.rename(columns=lambda x: x.strip())
f2 = r'C:\Users\louis\Documents\GitHub\chiralpl\source\CT_JAGG_abs.csv'
f2 = pd.read_csv(f2,skiprows=3)
f2 = f2.rename(columns=lambda x: x.strip())

fig,ax = plt.subplots()
ax.plot(f['Energy'], f['ABSX'])
ax.plot(f2['Energy'], f2['ABSX'])

# ax.set_ylim(0,0.1)
