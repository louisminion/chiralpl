# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv(r"C:\Users\louis\Documents\GitHub\chiralpl\LOUISPL_pl.csv",skiprows=3)
df = df.rename(columns=lambda x: x.strip())
fig,ax = plt.subplots()
ax.plot(df['Energy'], df['PLX'],color='blue')
ax.plot(df['Energy'], df['PLY'],color='blue')
ax.plot(df['Energy'], df['PLZ'],color='blue')
df = pd.read_csv(r"C:\Users\louis\Documents\GitHub\chiralpl\LOUISPL_abs.csv",skiprows=3)
df = df.rename(columns=lambda x: x.strip())
# fig,ax = plt.subplots()
ax2=ax.twinx()
ax2.plot(df['Energy'], df['ABSX'],color='red')
ax2.plot(df['Energy'], df['ABSY'],color='red')
ax2.plot(df['Energy'], df['ABSZ'],color='red')
ax.set_xlim(10000,30000)
# Out:
# (10000.0, 30000.0)
